# %%
# eda

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re
from sklearn.feature_extraction.text import CountVectorizer
# Load the dataset
df = pd.read_excel("C:/Users/adedi/OneDrive/Projects/G-customer-review-sentiment/cleaned_reviews.xlsx") 
df.head()
# Out:
#       brand                model   price  Ratings  \
# 0  Hey Dude  Wally Linen Natural  $64.99        5
# 1  Hey Dude  Wally Linen Natural  $64.99        5
# 2  Hey Dude  Wally Linen Natural  $64.99        5
# 3  Hey Dude  Wally Linen Natural  $64.99        5
# 4  Hey Dude  Wally Linen Natural  $64.99        5
#
#                                    processed_reviews Sentiment
# 0  bought son love wear almost everi day definit ...  Positive
# 1                                 get lot compliment  Positive
# 2                                          love dude  Positive
# 3                                               love  Positive
# 4                                    probabl favorit  Positive

# %%
# Set visualization style
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("viridis")

# Create the DataFrame from the provided data


# Basic data preparation
# Convert price to numeric
df['price_numeric'] = df['price'].str.replace('$', '').astype(float)

# Check for missing values 
print("Dataset Shape:", df.shape)
print("\nDataset Information:")
print(df.info())

print("\nSummary Statistics:")
print(df.describe(include='all'))

print("\nMissing Values:")
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0] if any(missing_values > 0) else "No missing values")

# Add word count in reviews
df['word_count'] = df['processed_reviews'].str.split().str.len()

# Data Analysis
print("\n--- Distribution Analyses ---")

# Rating Distribution
print("\nRating Distribution:")
rating_counts = df['Ratings'].value_counts().sort_index()
print(rating_counts)

plt.figure(figsize=(10, 6))
sns.countplot(x='Ratings', data=df, order=sorted(df['Ratings'].unique()))
plt.title('Distribution of Ratings')
plt.xlabel('Rating (1-5 stars)')
plt.ylabel('Count')
plt.savefig('rating_distribution.png')
plt.close()

# Price Distribution
plt.figure(figsize=(12, 6))
sns.histplot(df['price_numeric'], bins=10, kde=True)
plt.title('Price Distribution')
plt.xlabel('Price ($)')
plt.ylabel('Frequency')
plt.savefig('price_distribution.png')
plt.close()

print(f"\nPrice Range: ${df['price_numeric'].min()} - ${df['price_numeric'].max()}")
print(f"Average Price: ${df['price_numeric'].mean():.2f}")
print(f"Median Price: ${df['price_numeric'].median():.2f}")

# Brand Analysis
print("\nBrands by Frequency:")
brand_counts = df['brand'].value_counts()
print(brand_counts)

plt.figure(figsize=(10, 6))
brand_counts.plot(kind='bar')
plt.title('Brands by Frequency')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('brands_frequency.png')
plt.close()

# Model Analysis
print("\nModels by Frequency:")
model_counts = df['model'].value_counts()
print(model_counts)

plt.figure(figsize=(12, 6))
model_counts.head(10).plot(kind='bar')
plt.title('Models by Frequency')
plt.xlabel('Model')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('models_frequency.png')
plt.close()

# Rating by Brand Analysis
print("\nAverage Rating by Brand:")
avg_rating_by_brand = df.groupby('brand')['Ratings'].mean().sort_values(ascending=False)
print(avg_rating_by_brand)

plt.figure(figsize=(12, 8))  # Increased figure size for better readability 
sns.barplot(x=avg_rating_by_brand.head(20).index, y=avg_rating_by_brand.head(20).values)
plt.title('Average Rating by Top 20 Brands')
plt.xlabel('Brand')
plt.ylabel('Average Rating')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('avg_rating_by_brand.png')
plt.close()

# Price by Brand Analysis
print("\nAverage Price by Brand:")
avg_price_by_brand = df.groupby('brand')['price_numeric'].mean().sort_values(ascending=False)
print(avg_price_by_brand)

plt.figure(figsize=(12, 8))  # Increased figure size
sns.barplot(x=avg_price_by_brand.head(20).index, y=avg_price_by_brand.head(20).values)
plt.title('Average Price by Top 20 Brands')
plt.xlabel('Brand')
plt.ylabel('Average Price ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('avg_price_by_brand.png')
plt.close()

# Price by Model Analysis
print("\nAverage Price by Model:")
avg_price_by_model = df.groupby('model')['price_numeric'].mean().sort_values(ascending=False)
print(avg_price_by_model)

plt.figure(figsize=(14, 8))  # Even larger figure for model names
sns.barplot(x=avg_price_by_model.head(20).index, y=avg_price_by_model.head(20).values)
plt.title('Average Price by Top 20 Models')
plt.xlabel('Model')
plt.ylabel('Average Price ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('avg_price_by_model.png')
plt.close()

# Correlation between price and rating
print("\nCorrelation between Price and Rating:")
corr = df[['price_numeric', 'Ratings']].corr()
print(corr)

plt.figure(figsize=(10, 6))
sns.scatterplot(x='price_numeric', y='Ratings', data=df, alpha=0.6)
plt.title('Price vs. Rating')
plt.xlabel('Price ($)')
plt.ylabel('Rating')
plt.savefig('price_vs_rating.png')
plt.close()

# Review Text Analysis
print("\nReview Text Analysis:")
print("Average word count in reviews:", df['word_count'].mean())

plt.figure(figsize=(10, 6))
sns.histplot(df['word_count'], bins=10, kde=True)
plt.title('Word Count Distribution in Reviews')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.savefig('word_count_distribution.png')
plt.close()

# Word frequency analysis
all_reviews = ' '.join(df['processed_reviews'])
words = all_reviews.split()
word_counts = Counter(words).most_common(20)

print("\nMost common words in reviews:")
print(word_counts)

# Create DataFrame for word count visualization
word_df = pd.DataFrame(word_counts, columns=['word', 'count'])

plt.figure(figsize=(12, 6))
sns.barplot(x='word', y='count', data=word_df)
plt.title('Most Common Words in Reviews')
plt.xlabel('Word')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('common_words.png')
plt.close()

# Sentiment Analysis (since all are positive in this dataset, just showing distribution)
print("\nSentiment Distribution:")
sentiment_counts = df['Sentiment'].value_counts()
print(sentiment_counts)

plt.figure(figsize=(8, 6))
sentiment_counts.plot(kind='bar')
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig('sentiment_distribution.png')
plt.close()

# Correlation Matrix for Numeric Features
numeric_cols = ['Ratings', 'price_numeric', 'word_count']
numeric_df = df[numeric_cols]

plt.figure(figsize=(8, 6))
correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Numeric Features')
plt.tight_layout()
plt.savefig('correlation_matrix.png')
plt.close()

print("\nCorrelation Matrix:")
print(correlation_matrix)

# Advanced Analysis: Term Frequency Analysis by Brand
print("\nTop terms by brand:")
vectorizer = CountVectorizer(max_features=20)

for brand in df['brand'].unique():
    brand_reviews = ' '.join(df[df['brand'] == brand]['processed_reviews'])
    
    # Skip if no reviews
    if not brand_reviews:
        continue
        
    X = vectorizer.fit_transform([brand_reviews])
    terms = vectorizer.get_feature_names_out()
    frequencies = X.toarray()[0]
    
    # Create DataFrame for term frequencies
    term_freq = pd.DataFrame({'term': terms, 'frequency': frequencies})
    term_freq = term_freq.sort_values('frequency', ascending=False)
    
    print(f"\nTop 10 terms for {brand}:")
    print(term_freq.head(10))
    
    plt.figure(figsize=(10, 6))
    sns.barplot(x='term', y='frequency', data=term_freq.head(10))
    plt.title(f'Top 10 Terms for {brand}')
    plt.xlabel('Term')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig(f'{brand}_top_terms.png')
    plt.close()

# Advanced Analysis: Rating vs Word Count
plt.figure(figsize=(10, 6))
sns.boxplot(x='Ratings', y='word_count', data=df)
plt.title('Word Count by Rating')
plt.xlabel('Rating')
plt.ylabel('Word Count')
plt.savefig('word_count_by_rating.png')
plt.close()

# Model comparison by brand
print("\nModel distribution by brand:")
model_by_brand = pd.crosstab(df['brand'], df['model'])
print(model_by_brand)

# Grouped bar chart for price by model and brand
plt.figure(figsize=(14, 8))
sns.barplot(x='model', y='price_numeric', hue='brand', data=df)
plt.title('Price by Model and Brand')
plt.xlabel('Model')
plt.ylabel('Price ($)')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Brand')
plt.tight_layout()
plt.savefig('price_by_model_brand.png')
plt.close()

# Print summary of findings
print("\n=== Summary of Findings ===")
print(f"1. Dataset contains information on {df.shape[0]} shoe reviews.")
print(f"2. Average rating across all shoes is {df['Ratings'].mean():.2f} out of 5 stars.")
print(f"3. Average price is ${df['price_numeric'].mean():.2f}.")

if not brand_counts.empty:
    print(f"4. Most popular brand is {brand_counts.index[0]} with {brand_counts.iloc[0]} products.")

if not avg_price_by_brand.empty:
    print(f"5. Most expensive brand on average is {avg_price_by_brand.index[0]} at ${avg_price_by_brand.iloc[0]:.2f}.")

if not avg_rating_by_brand.empty:
    print(f"6. All brands maintain high ratings with most at {avg_rating_by_brand.iloc[0]:.2f} stars.")

print(f"7. Correlation between price and rating is {corr.loc['price_numeric', 'Ratings']:.3f}.")
print(f"8. Average word count in reviews is {df['word_count'].mean():.1f} words.")
print(f"9. All reviews in the dataset have a {sentiment_counts.index[0]} sentiment.")
print(f"10. Most common words in reviews include: {', '.join([word for word, count in word_counts[:5]])}")

print("\nEDA complete. Visualizations saved to files.")
# Out:
# Dataset Shape: (2959, 7)
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2959 entries, 0 to 2958
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              2959 non-null   object
#  1   model              2959 non-null   object
#  2   price              2959 non-null   object
#  3   Ratings            2959 non-null   int64
#  4   processed_reviews  2959 non-null   object
#  5   Sentiment          2959 non-null   object
#  6   price_numeric      2959 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 161.9+ KB
# None
#
# Summary Statistics:
#            brand      model   price      Ratings processed_reviews Sentiment  \
# count       2959       2959    2959  2959.000000              2959      2959
# unique       109        757     383          NaN              2832         3
# top     SKECHERS  Authentic  $79.95          NaN        great shoe  Positive
# freq         325         17      79          NaN                14      2380
# mean         NaN        NaN     NaN     4.337952               NaN       NaN
# std          NaN        NaN     NaN     1.216026               NaN       NaN
# min          NaN        NaN     NaN     1.000000               NaN       NaN
# 25%          NaN        NaN     NaN     4.000000               NaN       NaN
# 50%          NaN        NaN     NaN     5.000000               NaN       NaN
# 75%          NaN        NaN     NaN     5.000000               NaN       NaN
# max          NaN        NaN     NaN     5.000000               NaN       NaN
#
#         price_numeric
# count     2959.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean        97.399148
# std         48.830078
# min         23.650000
# 25%         66.210000
# 50%         84.950000
# 75%        110.000000
# max        425.000000
#
# Missing Values:
# No missing values
#
# --- Distribution Analyses ---
#
# Rating Distribution:
# Ratings
# 1     183
# 2     181
# 3     215
# 4     254
# 5    2126
# Name: count, dtype: int64
#
# Price Range: $23.65 - $425.0
# Average Price: $97.40
# Median Price: $84.95
#
# Brands by Frequency:
# brand
# SKECHERS                 325
# Vans                     198
# Cole Haan                115
# Hey Dude                 107
# Propet                    80
#                         ...
# HUGO                       1
# To Boot New York           1
# Under Armour               1
# Eastland 1955 Edition      1
# Vince Camuto               1
# Name: count, Length: 109, dtype: int64
#
# Models by Frequency:
# model
# Authentic                  17
# Tree Runner                15
# Royal Lo Lace Up           13
# Soft 7 Premier Sneakers    12
# SK8-Hi                     10
#                            ..
# Manteca 4 Hi                1
# Fu Authentic™               1
# Elite Active                1
# Phoenix                     1
# Leo                         1
# Name: count, Length: 757, dtype: int64
#
# Average Rating by Brand:
# brand
# TravisMathew             5.000000
# Dunham                   5.000000
# Timberland               5.000000
# Allbirds                 5.000000
# Under Armour             5.000000
#                            ...
# Forsake                  3.000000
# Vince Camuto             3.000000
# Five Ten                 3.000000
# Dansko                   2.666667
# Eastland 1955 Edition    1.000000
# Name: Ratings, Length: 109, dtype: float64
#
# Average Price by Brand:
# brand
# To Boot New York    399.000000
# Magnanni            379.500000
# Mephisto            316.656667
# Allen Edmonds       278.615385
# Martin Dingman      240.000000
#                        ...
# Fila                 47.100000
# Keds                 45.980000
# SeaVees              44.200000
# Native Shoes         39.439286
# LABEL                38.350000
# Name: price_numeric, Length: 109, dtype: float64
#
# Average Price by Model:
# model
# Phoenix                                           425.00
# Derrick                                           399.00
# Match                                             398.95
# Ibiza                                             398.00
# Steve Air                                         358.90
#                                                    ...
# Striper II CVO Canvas                              34.99
# Chuck Taylor All Star Leather High Top Sneaker     32.00
# Miles                                              31.46
# Go-To Low                                          26.00
# Jefferson Sugarlite Clog                           23.65
# Name: price_numeric, Length: 757, dtype: float64
#
# Correlation between Price and Rating:
#                price_numeric   Ratings
# price_numeric       1.000000 -0.020042
# Ratings            -0.020042  1.000000
#
# Review Text Analysis:
# Average word count in reviews: 18.9976343359243
#
# Most common words in reviews:
# [('shoe', 2866), ('comfort', 1187), ('size', 928), ('great', 846), ('wear', 820), ('fit', 796), ('look', 783), ('pair', 637), ('like', 612), ('love', 576), ('feet', 439), ('good', 425), ('feel', 336), ('order', 335), ('walk', 331), ('wide', 323), ('would', 319), ('day', 315), ('get', 310), ('im', 309)]
#
# Sentiment Distribution:
# Sentiment
# Positive    2380
# Negative     364
# Neutral      215
# Name: count, dtype: int64
#
# Correlation Matrix:
#                 Ratings  price_numeric  word_count
# Ratings        1.000000      -0.020042   -0.125070
# price_numeric -0.020042       1.000000    0.114488
# word_count    -0.125070       0.114488    1.000000
#
# Top terms by brand:
#
# Top 10 terms for Hey Dude:
#        term  frequency
# 4   comfort         40
# 14     love         37
# 17     shoe         30
# 8     great         23
# 18     size         20
# 6      dude         18
# 19     wear         17
# 7       fit         17
# 9       hey         15
# 16  perfect         14
#
# Top 10 terms for Columbia:
#          term  frequency
# 16       shoe         26
# 7        good          8
# 1     comfort          8
# 17       size          7
# 11       like          7
# 8       great          6
# 10         im          5
# 12       look          5
# 5         fit          5
# 15  recommend          4
#
# Top 10 terms for Polo Ralph Lauren:
#        term  frequency
# 15     shoe         33
# 5     great         17
# 3       fit         14
# 8      look         12
# 16     size         11
# 19    would         10
# 18     wear          7
# 2   comfort          6
# 4      good          6
# 0    better          5
#
# Top 10 terms for Heelys:
#       term  frequency
# 18    size          8
# 2    great          4
# 17    shoe          4
# 5     love          3
# 11   order          3
# 0    child          2
# 1      got          2
# 16   right          2
# 19   small          2
# 6   narrow          2
#
# Top 10 terms for Vans:
#        term  frequency
# 14     shoe        208
# 17      van        107
# 18     wear         75
# 12     love         70
# 15     size         68
# 1   comfort         59
# 3      feet         58
# 5       fit         55
# 10     like         51
# 8     great         49
#
# Top 10 terms for Tommy Hilfiger:
#        term  frequency
# 15     shoe         10
# 6     great          6
# 7      like          5
# 8      look          4
# 16  sneaker          4
# 19     wear          3
# 3    especi          3
# 5      feel          3
# 12     pair          2
# 18    still          2
#
# Top 10 terms for Sperry:
#        term  frequency
# 14     shoe         46
# 6     great         27
# 1   comfort         25
# 9      look         22
# 4       fit         20
# 18   sperri         18
# 10     love         16
# 19     wear         16
# 8      like         15
# 16  sneaker         14
#
# Top 10 terms for PUMA:
#        term  frequency
# 13     shoe         31
# 14     size         26
# 11     puma         21
# 7      look         15
# 1   comfort         15
# 3       fit         12
# 18     wear         10
# 5     great         10
# 16    style          9
# 6      like          9
#
# Top 10 terms for adidas Originals:
#        term  frequency
# 16     shoe         13
# 19     wear         10
# 1     adida         10
# 4       fit          9
# 6      good          8
# 9      look          8
# 12  perfect          7
# 17     size          6
# 3   comfort          6
# 13  qualiti          6
#
# Top 10 terms for Timberland:
#        term  frequency
# 0       big          4
# 4      good          4
# 15     size          4
# 18     wear          3
# 6     great          3
# 7      look          3
# 11  qualiti          2
# 16   though          2
# 14     shoe          2
# 13      run          2
#
# Top 10 terms for ASICS Sportstyle:
#      term  frequency
# 16   shoe         11
# 5    feet          6
# 8   great          5
# 19   walk          4
# 3     day          4
# 6    felt          4
# 1   comfi          3
# 18  super          3
# 17  style          3
# 0      95          3
#
# Top 10 terms for Gola:
#        term  frequency
# 12     shoe         29
# 13     size         27
# 3       fit         19
# 18     wear         15
# 8      look         15
# 2   comfort         12
# 15  sneaker         11
# 4      gola         11
# 5     great          9
# 6        im          9
#
# Top 10 terms for Native Shoes:
#      term  frequency
# 11   shoe         12
# 2    feet          8
# 15    toe          8
# 18   wear          7
# 6      im          7
# 19   work          6
# 14  theyr          6
# 12   size          6
# 4      go          5
# 5   great          5
#
# Top 10 terms for SeaVees:
#        term  frequency
# 14     shoe          7
# 6      like          5
# 2   comfort          4
# 15     size          4
# 19     wear          3
# 5    larger          3
# 13    remov          2
# 18    think          2
# 17     sole          2
# 16  sneaker          2
#
# Top 10 terms for SKECHERS:
#        term  frequency
# 12     shoe        269
# 1   comfort        135
# 6     great         80
# 18     wear         75
# 11     pair         64
# 4       fit         59
# 8      look         57
# 15     slip         56
# 17     walk         53
# 14  skecher         51
#
# Top 10 terms for Converse:
#        term  frequency
# 12     shoe         31
# 13     size         28
# 17     wear         18
# 3   convers         15
# 1     chuck         14
# 10    order         13
# 11     pair         11
# 7        im         10
# 14  support         10
# 2   comfort          9
#
# Top 10 terms for adidas Running:
#        term  frequency
# 2      good          3
# 1   comfort          3
# 3     great          2
# 15    still          2
# 8   qualiti          2
# 11     shoe          2
# 0        20          1
# 13     snow          1
# 18  support          1
# 17  stylish          1
#
# Top 10 terms for TOMS:
#        term  frequency
# 11     shoe         22
# 18     wear         10
# 12     size         10
# 0   comfort          8
# 17      tom          8
# 4     great          8
# 16   summer          5
# 6      like          5
# 14     sock          5
# 9   qualiti          5
#
# Top 10 terms for Fila:
#      term  frequency
# 10   size          4
# 9    shoe          4
# 2   great          3
# 1     box          3
# 18    toe          2
# 11  small          2
# 0      11          2
# 5   order          2
# 4   least          2
# 3    half          2
#
# Top 10 terms for On:
#        term  frequency
# 12     shoe         65
# 3   comfort         28
# 13     size         23
# 6     great         20
# 9      look         17
# 5       fit         15
# 17     walk         13
# 8      like         12
# 19    would         11
# 2     cloud         11
#
# Top 10 terms for OluKai:
#        term  frequency
# 16     shoe         63
# 2   comfort         29
# 17     size         29
# 18     wear         26
# 7     great         21
# 9      like         17
# 11     look         14
# 3      dont         12
# 15     pair         12
# 5       fit         11
#
# Top 10 terms for Josef Seibel:
#       term  frequency
# 14    shoe         14
# 15    size         11
# 10   order          6
# 12  return          6
# 13  seibel          5
# 1    color          5
# 2    great          4
# 11    pair          3
# 18    walk          3
# 17   style          3
#
# Top 10 terms for Nunn Bush:
#        term  frequency
# 14     shoe         72
# 2   comfort         42
# 7     great         27
# 5       fit         25
# 9      look         17
# 12     pair         12
# 8      like         12
# 10     love         11
# 18     wear         11
# 0      bush         10
#
# Top 10 terms for ECCO Sport:
#        term  frequency
# 16     shoe         15
# 17     size          8
# 3   comfort          8
# 8       fit          8
# 5      ecco          7
# 12     like          6
# 13     look          6
# 10    great          5
# 6      feet          5
# 15    order          4
#
# Top 10 terms for Mephisto:
#         term  frequency
# 13      shoe         42
# 8   mephisto         20
# 16      wear         12
# 14      size         12
# 19      year         10
# 11      pair          9
# 17     white          8
# 0    comfort          8
# 10     order          8
# 6       look          6
#
# Top 10 terms for Florsheim:
#          term  frequency
# 15       shoe         49
# 2     comfort         33
# 18       wear         21
# 11       look         20
# 10      great         15
# 16       size         13
# 6   florsheim         12
# 0      casual         11
# 9        good         10
# 17       walk         10
#
# Top 10 terms for DC:
#        term  frequency
# 16     shoe         54
# 17     size         18
# 13     pair         18
# 2   comfort         14
# 4       fit         12
# 7     great         11
# 11     love         10
# 12    order         10
# 19    zappo          9
# 3        dc          9
#
# Top 10 terms for Propet:
#        term  frequency
# 13     shoe        103
# 2       fit         37
# 17     wide         27
# 11     pair         27
# 1      feet         26
# 7      look         25
# 10    order         23
# 14     size         23
# 5     great         23
# 0   comfort         22
#
# Top 10 terms for Sanuk:
#        term  frequency
# 1   comfort         23
# 13     shoe         17
# 11     pair         14
# 14     size         12
# 17     wear         11
# 5     great         11
# 3       fit          9
# 12    sanuk          9
# 10      one          8
# 7      look          8
#
# Top 10 terms for Saucony Originals:
#        term  frequency
# 11     shoe         25
# 12     size         12
# 2   comfort         11
# 10  sauconi          9
# 6      like          9
# 7      look          9
# 1     color          8
# 16     walk          6
# 19     year          6
# 8      love          6
#
# Top 10 terms for Birkenstock:
#            term  frequency
# 11         shoe         18
# 0   birkenstock         13
# 18        width          8
# 3          feet          8
# 12         size          8
# 9       perfect          7
# 17         wear          7
# 10       sandal          7
# 5         footb          7
# 1       comfort          6
#
# Top 10 terms for Johnston & Murphy:
#        term  frequency
# 14     shoe         70
# 3   comfort         36
# 11     pair         30
# 9      look         28
# 18     wear         22
# 10     love         18
# 8      like         18
# 7     great         16
# 6       fit         15
# 1    bought         13
#
# Top 10 terms for adidas:
#      term  frequency
# 16   size          9
# 3     fit          7
# 6    like          5
# 7    look          5
# 12  order          5
# 0   adida          4
# 18  women          4
# 4     get          4
# 1   color          4
# 13   pair          3
#
# Top 10 terms for johnnie-O:
#          term  frequency
# 17      style          3
# 10       love          2
# 16       shoe          2
# 5       great          2
# 1     comfort          2
# 11        low          1
# 18      tough          1
# 15        run          1
# 14  recommend          1
# 13    qualiti          1
#
# Top 10 terms for Martin Dingman:
#        term  frequency
# 14     shoe          6
# 15     slip          4
# 19     time          3
# 1     brand          3
# 17    style          3
# 16     sock          3
# 13   return          2
# 12  qualiti          2
# 11  perfect          2
# 0    bought          2
#
# Top 10 terms for etnies:
#      term  frequency
# 14   shoe         54
# 7   great         19
# 15   size         19
# 9    look         13
# 2    etni         10
# 5     get         10
# 16  skate          9
# 4     fit          9
# 1    dont          9
# 19   year          8
#
# Top 10 terms for Reebok Lifestyle:
#        term  frequency
# 14     shoe         64
# 2   comfort         32
# 8     great         31
# 10     look         28
# 11     love         22
# 19     wear         20
# 9      like         16
# 15     size         16
# 17    style         15
# 1     color         14
#
# Top 10 terms for Steve Madden:
#        term  frequency
# 13     shoe         21
# 8      like         11
# 0        12         10
# 9      look         10
# 17     wear          9
# 1   comfort          8
# 5       fit          7
# 16      toe          7
# 14     size          7
# 18    would          6
#
# Top 10 terms for Reef:
#        term  frequency
# 13     shoe         24
# 3   comfort          9
# 6     great          7
# 5       fit          6
# 14     size          6
# 18     wear          5
# 10  perfect          4
# 2     color          4
# 16  support          4
# 9      pair          4
#
# Top 10 terms for Frye:
#        term  frequency
# 15     shoe         12
# 10     look          7
# 3      foot          7
# 2       fit          5
# 16     size          5
# 5     great          4
# 6        im          4
# 9      like          4
# 1   comfort          4
# 11   narrow          4
#
# Top 10 terms for ALDO:
#         term  frequency
# 2       look          5
# 1    comfort          5
# 14      shoe          3
# 0   although          1
# 11    realli          1
# 18     stiff          1
# 17     stain          1
# 16      sole          1
# 15     sleek          1
# 13    sensit          1
#
# Top 10 terms for Calvin Klein:
#      term  frequency
# 12   shoe         10
# 13   size          7
# 0     big          4
# 7    look          4
# 2    good          3
# 18  white          3
# 17    tri          3
# 14  small          3
# 11   seem          2
# 16  still          2
#
# Top 10 terms for ASICS:
#        term  frequency
# 14     shoe          5
# 0    casual          2
# 7      love          2
# 18    split          2
# 1   comfort          2
# 19    tongu          2
# 5      like          2
# 3        im          2
# 2       fit          2
# 6      look          1
#
# Top 10 terms for Emerica:
#        term  frequency
# 14     shoe         17
# 16    skate         11
# 15     size          8
# 6       fit          7
# 5      fine          5
# 8     great          5
# 10     lace          4
# 2   emerica          4
# 3      ever          4
# 17     sole          4
#
# Top 10 terms for Merrell Work:
#        term  frequency
# 14     shoe         16
# 1   comfort         12
# 13     pair         11
# 19     work         10
# 18     wear          8
# 0      boot          7
# 8      look          5
# 9      love          5
# 5     great          5
# 4       fit          5
#
# Top 10 terms for BILLY Footwear:
#       term  frequency
# 13    shoe         57
# 1    billi         13
# 19  zipper         12
# 17    wear         12
# 11     put         11
# 0      afo         11
# 9     love         10
# 5      get         10
# 3     easi         10
# 15     son         10
#
# Top 10 terms for New Balance Numeric:
#        term  frequency
# 12     shoe         56
# 13     size         20
# 2       fit         19
# 0   comfort         17
# 5     great         15
# 7      look         15
# 18     wide         14
# 3      foot         13
# 17     wear         13
# 8    narrow         13
#
# Top 10 terms for UGG:
#        term  frequency
# 12     shoe         13
# 13     size         11
# 9      look         10
# 18     wear          8
# 3   comfort          7
# 5       fit          7
# 4      feet          6
# 8      like          6
# 6     great          5
# 0        10          4
#
# Top 10 terms for Vince Camuto:
#       term  frequency
# 0     arch          1
# 1   enough          1
# 2    insid          1
# 3      pad          1
# 4     sole          1
# 5  support          1
#
# Top 10 terms for Lakai:
#        term  frequency
# 10     shoe         31
# 0   comfort         10
# 5     lakai          9
# 7      look          9
# 1      feel          9
# 11     size          8
# 12    skate          7
# 4     great          7
# 18     wear          7
# 8      love          7
#
# Top 10 terms for adidas Outdoor:
#       term  frequency
# 14    shoe          8
# 2    adida          6
# 19   would          4
# 12     run          3
# 17  terrex          3
# 6       go          3
# 8     look          3
# 9      one          3
# 18    wear          2
# 16   style          2
#
# Top 10 terms for ECCO:
#        term  frequency
# 15     shoe         71
# 3      ecco         35
# 2   comfort         29
# 16     size         27
# 19     wear         19
# 9    narrow         19
# 18     soft         18
# 6     great         18
# 5       fit         17
# 10      one         16
#
# Top 10 terms for Allen Edmonds:
#        term  frequency
# 16  sneaker         22
# 14     shoe         16
# 3   comfort         13
# 9      look         12
# 5       fit         11
# 12  qualiti         11
# 18     wear          9
# 11     pair          9
# 0     allen          8
# 2    casual          8
#
# Top 10 terms for Globe:
#        term  frequency
# 14     shoe         63
# 13     pair         16
# 2   comfort         15
# 15     size         15
# 16    skate         14
# 11     love         13
# 8     great         12
# 9      like         12
# 6     globe         11
# 12    order         11
#
# Top 10 terms for Five Ten:
#       term  frequency
# 13    shoe         15
# 14    size         10
# 12    ride          8
# 4      fit          6
# 10    pair          4
# 11  realli          4
# 17     toe          4
# 19    well          4
# 7     like          4
# 3    first          4
#
# Top 10 terms for Ariat:
#        term  frequency
# 17     shoe         24
# 1   comfort         18
# 10     like         12
# 18     wear          8
# 14     pair          8
# 5       fit          6
# 11     love          6
# 3      dont          5
# 4      dude          5
# 7     great          5
#
# Top 10 terms for Vince:
#        term  frequency
# 11     shoe          5
# 12     size          5
# 1       big          4
# 4     order          3
# 19     wear          2
# 2      like          2
# 3    normal          2
# 7   purchas          2
# 14    still          1
# 18     vinc          1
#
# Top 10 terms for Lacoste:
#        term  frequency
# 15     shoe         16
# 1   comfort         10
# 4       fit          9
# 7     great          8
# 16     size          8
# 10     look          5
# 2      feel          5
# 12   narrow          5
# 3      feet          4
# 6      good          4
#
# Top 10 terms for HUGO:
#    term  frequency
# 0  nice          1
# 1  shoe          1
#
# Top 10 terms for Stacy Adams:
#        term  frequency
# 12     shoe         11
# 1   comfort         11
# 8      look          7
# 18     wear          6
# 15     sole          5
# 4     great          3
# 0    casual          2
# 17      use          2
# 16    theyr          2
# 14     slip          2
#
# Top 10 terms for COACH:
#        term  frequency
# 19     wide          3
# 7      look          3
# 11      run          2
# 13     size          2
# 1     great          2
# 18    white          1
# 17  wellmad          1
# 16   though          1
# 15    there          1
# 14   smooth          1
#
# Top 10 terms for BOBS from SKECHERS:
#        term  frequency
# 13     shoe         24
# 3   comfort         15
# 2     color          7
# 11     love          7
# 14     slip          7
# 18     wear          6
# 5       fit          5
# 6      good          5
# 9      like          5
# 10     look          4
#
# Top 10 terms for Magnanni:
#         term  frequency
# 16      shoe          6
# 7       pair          4
# 4       look          4
# 19      wear          3
# 2        fit          3
# 1     expens          2
# 0    exchang          2
# 5       love          2
# 3       hope          2
# 6   painless          1
#
# Top 10 terms for Johnston & Murphy Collection:
#        term  frequency
# 15     shoe         21
# 8      look          9
# 18     wear          8
# 16     size          8
# 5     great          8
# 7      like          6
# 13   realli          5
# 10     nice          4
# 6   leather          4
# 1   comfort          4
#
# Top 10 terms for Cole Haan:
#        term  frequency
# 13     shoe         98
# 1   comfort         49
# 4       fit         40
# 9      look         35
# 6     great         34
# 17     wear         31
# 14     size         30
# 0      cole         26
# 5      good         25
# 8      like         25
#
# Top 10 terms for Osiris:
#        term  frequency
# 11     shoe         33
# 4     great         13
# 1       fit         12
# 12     size         12
# 7      look         10
# 8      love         10
# 0   comfort          7
# 18     well          6
# 14    small          6
# 10    osiri          6
#
# Top 10 terms for Teva:
#        term  frequency
# 12     shoe         14
# 18     wear         12
# 13     size          9
# 2   comfort          8
# 7      like          7
# 11      run          6
# 6      lace          6
# 0      arch          5
# 14  sneaker          5
# 10      put          5
#
# Top 10 terms for Michael Kors:
#        term  frequency
# 2       fit          4
# 3   perfect          3
# 0   comfort          2
# 1     didnt          2
# 12     size          2
# 19     wear          2
# 6    pretti          1
# 7   qualiti          1
# 8    return          1
# 9     rigid          1
#
# Top 10 terms for VEJA:
#        term  frequency
# 11     shoe         38
# 18     wear         25
# 12     size         24
# 4     great         21
# 0   comfort         20
# 2       fit         17
# 8      look         17
# 6      like         16
# 13  sneaker         16
# 3      good         15
#
# Top 10 terms for Oakley:
#         term  frequency
# 0    comfort          2
# 6       size          2
# 14      time          2
# 1   complain          2
# 9        son          2
# 8    sneaker          2
# 19     would          2
# 4        fit          2
# 3      first          2
# 2      didnt          2
#
# Top 10 terms for KEEN:
#        term  frequency
# 14     shoe         29
# 13     pair         21
# 7      keen         17
# 16  support         11
# 4      feet         10
# 0      arch          9
# 3   comfort          9
# 6     great          9
# 10     love          8
# 1    austin          7
#
# Top 10 terms for Peter Millar:
#        term  frequency
# 12     shoe         14
# 3     great          7
# 17     wear          5
# 0   comfort          4
# 13     size          4
# 18     work          3
# 4      like          3
# 5      look          3
# 15    theyr          3
# 16      toe          2
#
# Top 10 terms for Reebok:
#          term  frequency
# 18       shoe          9
# 7        like          5
# 4       great          4
# 8        look          3
# 1     comfort          3
# 0         box          2
# 14    purchas          2
# 11       nano          2
# 19  sweepstak          2
# 6      havent          2
#
# Top 10 terms for Pro-Keds:
#        term  frequency
# 9      look         11
# 16     shoe         10
# 10     love          9
# 3       fit          8
# 2   comfort          7
# 17  sneaker          7
# 6       ked          7
# 18     wear          6
# 12     pair          6
# 1        70          5
#
# Top 10 terms for Born:
#        term  frequency
# 3   comfort          8
# 10     shoe          7
# 6       fit          7
# 14    style          5
# 9      look          5
# 8     great          4
# 1    casual          3
# 18     work          3
# 17    tight          3
# 11     size          3
#
# Top 10 terms for Under Armour:
#         term  frequency
# 0     bandit          2
# 1      daili          1
# 18      wear          1
# 17       son          1
# 16    someth          1
# 15   similar          1
# 14  previous          1
# 13   preteen          1
# 12     pleas          1
# 11      play          1
#
# Top 10 terms for L.L.Bean:
#        term  frequency
# 10     shoe          5
# 6      look          5
# 14     time          2
# 1    casual          2
# 7      pair          2
# 19     well          2
# 5      long          2
# 4     great          2
# 3       fit          2
# 2   comfort          2
#
# Top 10 terms for victoria:
#        term  frequency
# 12     shoe          7
# 9      like          7
# 2      cute          5
# 18  support          4
# 5       fit          3
# 15  sneaker          3
# 1   comfort          3
# 13     size          3
# 0     brand          2
# 17     soon          2
#
# Top 10 terms for Merrell:
#        term  frequency
# 14     shoe         12
# 2   comfort          8
# 7     great          6
# 6       get          5
# 17    tongu          4
# 5       fit          4
# 0       bit          3
# 12     nice          3
# 18      use          3
# 16    tight          3
#
# Top 10 terms for LABEL:
#        term  frequency
# 14     shoe          5
# 1   comfort          3
# 3     great          3
# 4   leather          3
# 13  qualiti          3
# 0    clunki          2
# 17     well          2
# 15     sole          2
# 12    price          2
# 11     pair          2
#
# Top 10 terms for Hoka:
#        term  frequency
# 15     shoe         41
# 19     wide         20
# 8      hoka         17
# 2      feet         13
# 13     pair         13
# 18     wear         12
# 0   comfort          9
# 7     great          8
# 9        im          8
# 16     size          8
#
# Top 10 terms for SKECHERS Performance:
#        term  frequency
# 11     shoe         39
# 1   comfort         26
# 13     slip         17
# 17     wear         15
# 10     pair         13
# 16     walk         12
# 3       fit         12
# 6     great         12
# 14    style         10
# 18     wide          9
#
# Top 10 terms for Superga:
#        term  frequency
# 14     size         21
# 6      like          8
# 8      love          8
# 18     wear          7
# 16     sock          7
# 13     shoe          7
# 10    order          6
# 11   realli          6
# 3       fit          6
# 15  sneaker          5
#
# Top 10 terms for New Balance Classics:
#        term  frequency
# 12     shoe         56
# 13     size         25
# 11     pair         23
# 10      new         22
# 3       fit         21
# 0    balanc         19
# 15  support         15
# 1   comfort         14
# 5     great         14
# 8      look         13
#
# Top 10 terms for SAS:
#        term  frequency
# 12     shoe         76
# 0   comfort         26
# 11       sa         25
# 8      pair         17
# 5     great         16
# 2      feet         15
# 4       fit         13
# 7       one         12
# 1       day         12
# 17     wear         11
#
# Top 10 terms for Rockport:
#         term  frequency
# 14      shoe         49
# 0    comfort         20
# 12      pair         14
# 15      size         14
# 10      look         14
# 3        fit         14
# 7      great         13
# 16      wear         13
# 13  rockport         11
# 9       like          9
#
# Top 10 terms for PIKOLINOS:
#         term  frequency
# 6       shoe          2
# 0    comfort          1
# 1     except          1
# 2        fit          1
# 3    impress          1
# 4    qualiti          1
# 5  recommend          1
#
# Top 10 terms for Deer Stags:
#      term  frequency
# 14   shoe         15
# 4     fit          4
# 5   great          3
# 15   slip          3
# 8    lace          3
# 0    back          2
# 12   make          2
# 18   wear          2
# 17    tie          2
# 16  small          2
#
# Top 10 terms for To Boot New York:
#       term  frequency
# 0     arch          1
# 1  comfort          1
# 2  husband          1
# 3     like          1
# 4    littl          1
# 5   realli          1
# 6    style          1
# 7  support          1
#
# Top 10 terms for VIONIC:
#        term  frequency
# 11     shoe         34
# 0      arch         11
# 3      foot         11
# 2   comfort         10
# 15  support         10
# 19     wear          9
# 6      pair          7
# 9   qualiti          7
# 13  sneaker          7
# 1      back          6
#
# Top 10 terms for Clarks:
#        term  frequency
# 13     shoe         51
# 3   comfort         16
# 10     like         13
# 11     look         13
# 9   leather         11
# 7      heel         10
# 17     wear         10
# 16  support          8
# 2     clark          8
# 5      good          8
#
# Top 10 terms for Taos Footwear:
#        term  frequency
# 14     shoe         11
# 15     size          7
# 0        12          5
# 16  support          5
# 8     littl          4
# 18    width          4
# 17      toe          4
# 10     love          4
# 5        im          4
# 4     great          4
#
# Top 10 terms for Dr. Scholl's:
#        term  frequency
# 15     shoe         18
# 1   comfort          8
# 4      feet          6
# 5       fit          6
# 11     look          6
# 3        dr          5
# 16     size          5
# 0       buy          4
# 17     wear          4
# 14   scholl          4
#
# Top 10 terms for Eastland 1955 Edition:
#      term  frequency
# 0    good          1
# 1    look          1
# 2  person          1
# 3     pic          1
#
# Top 10 terms for ECCO Golf:
#           term  frequency
# 11        shoe          5
# 3         feel          3
# 4          fit          3
# 19       would          2
# 2       eyelet          2
# 5         look          2
# 6       medium          2
# 18  waterproof          2
# 8      previou          2
# 17       tongu          2
#
# Top 10 terms for Dunham:
#         term  frequency
# 17      shoe          5
# 19      well          3
# 8        one          3
# 18      wear          3
# 11      pair          3
# 1   accommod          2
# 0       2018          2
# 6       need          2
# 4       feet          2
# 3     enough          2
#
# Top 10 terms for Forsake:
#        term  frequency
# 12     shoe          2
# 0        90          1
# 1   comfort          1
# 2    expect          1
# 3       fit          1
# 4     great          1
# 5      high          1
# 6    larger          1
# 7      love          1
# 8       low          1
#
# Top 10 terms for Samuel Hubbard:
#       term  frequency
# 16    shoe         10
# 11  narrow          5
# 13  realli          4
# 10    look          3
# 17    size          3
# 5      fit          3
# 9     like          3
# 12    nice          3
# 18   width          2
# 15    said          2
#
# Top 10 terms for Orthofeet:
#        term  frequency
# 16     shoe         14
# 0   comfort          4
# 7     great          4
# 13      one          4
# 10     look          4
# 6      foot          3
# 4      feet          3
# 9      like          3
# 1       day          3
# 3      feel          3
#
# Top 10 terms for Allbirds:
#        term  frequency
# 2   comfort         38
# 13     shoe         27
# 11     love         13
# 8     great         12
# 12     pair         10
# 18     wear          9
# 9     light          8
# 0   allbird          6
# 19     worn          6
# 5      feel          6
#
# Top 10 terms for New Balance:
#        term  frequency
# 12     shoe         13
# 19     wide          6
# 5       fit          6
# 2   comfort          5
# 8      like          5
# 16  support          4
# 6      foot          4
# 17    tight          3
# 15     sock          3
# 13     size          3
#
# Top 10 terms for OOFOS:
#       term  frequency
# 14    shoe          9
# 16    size          5
# 11   order          5
# 10    like          3
# 1       12          3
# 13  return          3
# 19    wear          3
# 4     foot          3
# 7     good          2
# 8     high          2
#
# Top 10 terms for SOREL:
#           term  frequency
# 19        work          3
# 3        great          3
# 4         look          3
# 17  waterproof          3
# 13        shoe          3
# 1      comfort          2
# 18        well          2
# 0          age          2
# 2        dress          2
# 8        pleas          1
#
# Top 10 terms for Camper:
#        term  frequency
# 15     shoe         11
# 7       ive          5
# 8   leather          5
# 5     great          4
# 6        im          3
# 0     black          2
# 12     nice          2
# 18     walk          2
# 17  support          2
# 16    still          2
#
# Top 10 terms for TravisMathew:
#             term  frequency
# 1        comfort          7
# 6          great          7
# 17          shoe          5
# 8           pair          4
# 0          color          3
# 5            get          3
# 7    lightweight          3
# 18       stylish          2
# 16        second          2
# 19  travismathew          2
#
# Top 10 terms for Keds:
#        term  frequency
# 1        12          3
# 2     color          2
# 18    women          2
# 4      love          2
# 0        11          1
# 12     size          1
# 17     wish          1
# 16    width          1
# 15    updat          1
# 14  support          1
#
# Top 10 terms for Dansko:
#       term  frequency
# 13    shoe          4
# 19   zappo          3
# 2   dansko          2
# 3   experi          2
# 4      fit          2
# 5    order          2
# 6     pair          2
# 1    arriv          2
# 18   stiff          1
# 17   small          1
#
# Top 10 terms for Brooks:
#        term  frequency
# 1    collar          2
# 13     pair          2
# 0        10          1
# 18    thank          1
# 17  sneaker          1
# 16     slip          1
# 15  shorter          1
# 14  probabl          1
# 12     open          1
# 11    older          1
#
# Top 10 terms for Vibram FiveFingers:
#         term  frequency
# 12       run          6
# 19    vibram          5
# 14      size          4
# 6    husband          4
# 9       love          3
# 16     style          3
# 13      shoe          3
# 10       luv          3
# 7        kso          3
# 5   fivefing          3
#
# Model distribution by brand:
# model             08/63 Hermosa Plimsoll Standard  1010 - Tiago Lemos  237v1  \
# brand
# ALDO                                            0                   0      0
# ASICS                                           0                   0      0
# ASICS Sportstyle                                0                   0      0
# Allbirds                                        0                   0      0
# Allen Edmonds                                   0                   0      0
# ...                                           ...                 ...    ...
# adidas Outdoor                                  0                   0      0
# adidas Running                                  0                   0      0
# etnies                                          0                   0      0
# johnnie-O                                       0                   0      0
# victoria                                        0                   0      0
#
# model             272  2750 COTU Classic Sneaker  2750 Cotu Classic  \
# brand
# ALDO                0                          0                  0
# ASICS               0                          0                  0
# ASICS Sportstyle    0                          0                  0
# Allbirds            0                          0                  0
# Allen Edmonds       0                          0                  0
# ...               ...                        ...                ...
# adidas Outdoor      0                          0                  0
# adidas Running      0                          0                  0
# etnies              0                          0                  0
# johnnie-O           0                          0                  0
# victoria            0                          0                  0
#
# model             2750 Nappa  2750 OG  3-D Max Protect  300 Court  ...  \
# brand                                                              ...
# ALDO                       0        0                0          0  ...
# ASICS                      0        0                0          0  ...
# ASICS Sportstyle           0        0                0          0  ...
# Allbirds                   0        0                0          0  ...
# Allen Edmonds              0        0                0          0  ...
# ...                      ...      ...              ...        ...  ...
# adidas Outdoor             0        0                0          0  ...
# adidas Running             0        0                0          0  ...
# etnies                     0        0                0          0  ...
# johnnie-O                  0        0                0          0  ...
# victoria                   0        0                0          0  ...
#
# model             Wino G6 Slip-On  Winslow Waterproof  Wool Runner  \
# brand
# ALDO                            0                   0            0
# ASICS                           0                   0            0
# ASICS Sportstyle                0                   0            0
# Allbirds                        0                   0            5
# Allen Edmonds                   0                   0            0
# ...                           ...                 ...          ...
# adidas Outdoor                  0                   0            0
# adidas Running                  0                   0            0
# etnies                          0                   0            0
# johnnie-O                       0                   0            0
# victoria                        0                   0            0
#
# model             Wool Runner Go  Work Comfort Lo  \
# brand
# ALDO                           0                0
# ASICS                          0                0
# ASICS Sportstyle               0                0
# Allbirds                       5                0
# Allen Edmonds                  0                0
# ...                          ...              ...
# adidas Outdoor                 0                0
# adidas Running                 0                0
# etnies                         0                0
# johnnie-O                      0                0
# victoria                       0                0
#
# model             World Tour Classic Walking Shoe  XC4 Lancer Wing Tip  \
# brand
# ALDO                                            0                    0
# ASICS                                           0                    0
# ASICS Sportstyle                                0                    0
# Allbirds                                        0                    0
# Allen Edmonds                                   0                    0
# ...                                           ...                  ...
# adidas Outdoor                                  0                    0
# adidas Running                                  0                    0
# etnies                                          0                    0
# johnnie-O                                       0                    0
# victoria                                        0                    0
#
# model             XC4 TR3-Luxe Hybrid  Zerogrand WFA  \
# brand
# ALDO                                0              0
# ASICS                               0              0
# ASICS Sportstyle                    0              0
# Allbirds                            0              0
# Allen Edmonds                       0              0
# ...                               ...            ...
# adidas Outdoor                      0              0
# adidas Running                      0              0
# etnies                              0              0
# johnnie-O                           0              0
# victoria                            0              0
#
# model             Zinger - Ultimate Classic
# brand
# ALDO                                      0
# ASICS                                     0
# ASICS Sportstyle                          0
# Allbirds                                  0
# Allen Edmonds                             0
# ...                                     ...
# adidas Outdoor                            0
# adidas Running                            0
# etnies                                    0
# johnnie-O                                 0
# victoria                                  0
#
# [109 rows x 757 columns]
# C:\Users\adedi\AppData\Local\Temp\ipykernel_16408\954454305.py:261: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# C:\Users\adedi\AppData\Local\Temp\ipykernel_16408\954454305.py:261: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# C:\Users\adedi\AppData\Local\Temp\ipykernel_16408\954454305.py:262: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig('price_by_model_brand.png')
# === Summary of Findings ===
# 1. Dataset contains information on 2959 shoe reviews.
# 2. Average rating across all shoes is 4.34 out of 5 stars.
# 3. Average price is $97.40.
# 4. Most popular brand is SKECHERS with 325 products.
# 5. Most expensive brand on average is To Boot New York at $399.00.
# 6. All brands maintain high ratings with most at 5.00 stars.
# 7. Correlation between price and rating is -0.020.
# 8. Average word count in reviews is 19.0 words.
# 9. All reviews in the dataset have a Positive sentiment.
# 10. Most common words in reviews include: shoe, comfort, size, great, wear
#
# EDA complete. Visualizations saved to files.

# %%
import nltk
nltk.download('stopwords')
# Word cloud of reviews
try:
    from wordcloud import WordCloud
    import re
    from collections import Counter
    
    all_reviews = ' '.join(df['processed_reviews'])
    
    # Remove common English stopwords if nltk is installed
    try:
        from nltk.corpus import stopwords
        stop_words = set(stopwords.words('english'))
        
        def clean_text(text):
            text = text.lower()
            text = re.sub(r'[^\w\s]', '', text)
            words = text.split()
            words = [word for word in words if word not in stop_words]
            return ' '.join(words)
        
        cleaned_reviews = clean_text(all_reviews)
    except:
        # If nltk is not available, just do basic cleaning
        cleaned_reviews = all_reviews.lower()
        cleaned_reviews = re.sub(r'[^\w\s]', '', cleaned_reviews)
    
    wordcloud = WordCloud(width=800, height=400, background_color='white', max_words=100).generate(cleaned_reviews)
    
    plt.figure(figsize=(12, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title('Word Cloud of Reviews')
    plt.savefig('review_wordcloud.png')
    plt.close()
    
    # Most common words
    words = cleaned_reviews.split()
    word_counts = Counter(words).most_common(20)
    
    print("\nMost common words in reviews:")
    print(word_counts)
    
    # Create DataFrame for word count visualization
    word_df = pd.DataFrame(word_counts, columns=['word', 'count'])
    
    plt.figure(figsize=(12, 6))
    sns.barplot(x='word', y='count', data=word_df)
    plt.title('Most Common Words in Reviews')
    plt.xlabel('Word')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig('common_words.png')
    plt.close()
except ImportError:
    print("WordCloud not installed. Skipping word cloud generation.")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\adedi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Most common words in reviews:
# [('shoe', 2866), ('comfort', 1187), ('size', 928), ('great', 846), ('wear', 820), ('fit', 796), ('look', 783), ('pair', 637), ('like', 612), ('love', 576), ('feet', 439), ('good', 425), ('feel', 336), ('order', 335), ('walk', 331), ('wide', 323), ('would', 319), ('day', 315), ('get', 310), ('im', 309)]
